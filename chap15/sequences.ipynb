# %% [markdown]
# **Chapter 15 – Processing Sequences Using RNNs and CNNs**

# %% [markdown]
# <table align="left">
#   <td>
#     <a href="https://colab.research.google.com/github/ageron/handson-ml3/blob/main/15_processing_sequences_using_rnns_and_cnns.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#   </td>
#   <td>
#     <a target="_blank" href="https://kaggle.com/kernels/welcome?src=https://github.com/ageron/handson-ml3/blob/main/15_processing_sequences_using_rnns_and_cnns.ipynb"><img src="https://kaggle.com/static/images/open-in-kaggle.svg" /></a>
#   </td>
# </table>

# %% [markdown]
# # Setup

# %% [markdown]
# This project requires Python 3.7 or above:

# %%
import sys 

assert sys.version_info >= (3, 7)

# %% [markdown]
# And Tensorflow >= 2.8:

# %%
from packaging import version
import tensorflow as tf 

assert version.parse(tf.__version__) >= version.parse("2.8.0")
# Out:
# 2023-04-04 23:52:54.144365: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-04 23:53:11.338263: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-04-04 23:53:11.338299: I tensorflow/compiler/xla/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2023-04-04 23:53:44.436698: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2023-04-04 23:53:44.436946: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2023-04-04 23:53:44.436966: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %% [markdown]
# Definition of default font sizes to make the figures prettier:

# %%
import matplotlib.pyplot as plt 

plt.rc('font', size=14)
plt.rc('axes', labelsize=14, titlesize=14)
plt.rc('legend', fontsize=14)
plt.rc('xtick', labelsize=10)
plt.rc('ytick', labelsize=10)

# %% [markdown]
# Creation of the `images/rnn` folder(if it doesn't already exist), and define the `save_fig()` function which is used through this notebook to save the figures in high-resolution for the book:

# %%
from pathlib import Path

IMAGES_PATH = Path() / "images" / "rnn"
IMAGES_PATH.mkdir(parents=True, exist_ok=True)

def save_fig(fig_id, tight_layout=True, fig_extension="png", resolution=300):
    path = IMAGES_PATH / f"{fig_id}.{fig_extension}"
    if tight_layout:
        plt.tight_layout()
    plt.savefig(path, format=fig_extension, dpi=resolution)

# %% [markdown]
# This chapter can be very slow without a GPU, so let's make sure there's one, or else issue a warning:

# %%
if not tf.config.list_physical_devices('GPU'):
    print("No GPU was detected. Neural nets can be very slow without a GPU.")
    if "google.colab" in sys.modules:
        print("Go to Runtime > Change runtime and select a GPU hardware "
              "accelerator.")
    if "kaggle_secrets" in sys.modules:
        print("Go to Settings > Accelerator and select GPU.")
# Out:
# No GPU was detected. Neural nets can be very slow without a GPU.
# 2023-04-04 23:54:06.941511: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2023-04-04 23:54:06.950960: W tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:265] failed call to cuInit: UNKNOWN ERROR (303)
# 2023-04-04 23:54:06.951076: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (avtr): /proc/driver/nvidia/version does not exist

# %% [markdown]
# # Basic RNNs

# %% [markdown]
# Download the ridership data from the ageron/data project. It originally comes from Chicago's Transit Authority, and was downloaded from the [Chicago's Data Portal](https://homl.info/ridership).

# %%
tf.keras.utils.get_file(
    "ridership.tgz",
    "https://github.com/ageron/data/raw/main/ridership.tgz",
    cache_dir=".",
    extract=True
)
# Out:
# './datasets/ridership.tgz'

# %%
import pandas as pd
from pathlib import Path

path = Path("datasets/ridership/CTA_-_Ridership_-_Daily_Boarding_Totals.csv")
df = pd.read_csv(path, parse_dates=["service_date"])
df.columns = ["date", "day_type", "bus", "rail", "total"]  # shorter names
df = df.sort_values("date").set_index("date")
df = df.drop("total", axis=1)  # no need for total, it's just bus + rail
df = df.drop_duplicates()  # remove duplicated months (2011-10 and 2014-07)

# %%
df.head()
# Out:
#            day_type     bus    rail
# date
# 2001-01-01        U  297192  126455
# 2001-01-02        W  780827  501952
# 2001-01-03        W  824923  536432
# 2001-01-04        W  870021  550011
# 2001-01-05        W  890426  557917

# %% [markdown]
# Let's look at the first few months of 2019 (note that Pandas treats the range boundaries as inclusive):

# %%
import matplotlib.pyplot as plt

df["2019-03":"2019-05"].plot(grid=True, marker=".", figsize=(8, 3.5))
save_fig("daily_ridership_plot")  # extra code – saves the figure for the book
plt.show()

# %%
diff_7 = df[["bus", "rail"]].diff(7)["2019-03":"2019-05"]

fig, axs = plt.subplots(2, 1, sharex=True, figsize=(8, 5))
df.plot(ax=axs[0], legend=False, marker=".")  # original time series
df.shift(7).plot(ax=axs[0], grid=True, legend=False, linestyle=":")  # lagged
diff_7.plot(ax=axs[1], grid=True, marker=".")  # 7-day difference time series
axs[0].set_ylim([170_000, 900_000])  # extra code – beautifies the plot
save_fig("differencing_plot")  # extra code – saves the figure for the book
plt.show()

# %%
list(df.loc["2019-05-25":"2019-05-27"]["day_type"])
# Out:
# ['A', 'U', 'U']

# %% [markdown]
# Mean absolute error (MAE), also called mean absolute deviation (MAD):

# %%
diff_7.abs().mean()
# Out:
# bus     43915.608696
# rail    42143.271739
# dtype: float64

# %% [markdown]
# Mean absolute percentage error (MAPE):

# %%
targets = df[["bus", "rail"]]["2019-03":"2019-05"]
(diff_7 / targets).abs().mean()
# Out:
# bus     0.082938
# rail    0.089948
# dtype: float64

# %% [markdown]
# Now let's look at the yearly seasonality and the long-term trends:

# %%
period = slice("2001", "2019")
df_monthly = df.resample('M').mean()  # compute the mean for each month
rolling_average_12_months = df_monthly[period].rolling(window=12).mean()

fig, ax = plt.subplots(figsize=(8, 4))
df_monthly[period].plot(ax=ax, marker=".")
rolling_average_12_months.plot(ax=ax, grid=True, legend=False)
save_fig("long_term_ridership_plot")  # extra code – saves the figure for the book
plt.show()

# %%
df_monthly.diff(12)[period].plot(grid=True, marker=".", figsize=(8, 3))
save_fig("yearly_diff_plot")  # extra code – saves the figure for the book
plt.show()

# %% [markdown]
# If running on Colab or Kaggle, install the statsmodels library:

# %%
if "google.colab" in sys.modules:
    # %pip install -q -U statsmodels

# %%
from statsmodels.tsa.arima.model import ARIMA

origin, today = "2019-01-01", "2019-05-31"
rail_series = df.loc[origin:today]["rail"].asfreq("D")
model = ARIMA(rail_series,
              order=(1, 0, 0),
              seasonal_order=(0, 1, 1, 7))
model = model.fit()
y_pred = model.forecast()  # returns 427,758.6

# %%
y_pred[0]  # ARIMA forecast
# Out:
# 427758.6264438537

# %%
df["rail"].loc["2019-06-01"]  # target value
# Out:
# 379044

# %%
df["rail"].loc["2019-05-25"]  # naive forecast (value from one week earlier)
# Out:
# 426932

# %%
origin, start_date, end_date = "2019-01-01", "2019-03-01", "2019-05-31"
time_period = pd.date_range(start_date, end_date)
rail_series = df.loc[origin:end_date]["rail"].asfreq("D")
y_preds = []
for today in time_period.shift(-1):
    model = ARIMA(rail_series[origin:today],  # train on data up to "today"
                  order=(1, 0, 0),
                  seasonal_order=(0, 1, 1, 7))
    model = model.fit()  # note that we retrain the model every day!
    y_pred = model.forecast()[0]
    y_preds.append(y_pred)

y_preds = pd.Series(y_preds, index=time_period)
mae = (y_preds - rail_series[time_period]).abs().mean()  # returns 32,040.7

# %%
mae
# Out:
# 32040.72009476785

# %%
# extra code – displays the SARIMA forecasts
fig, ax = plt.subplots(figsize=(8, 3))
rail_series.loc[time_period].plot(label="True", ax=ax, marker=".", grid=True)
ax.plot(y_preds, color="r", marker=".", label="SARIMA Forecasts")
plt.legend()
plt.show()

# %%
# extra code – shows how to plot the Autocorrelation Function (ACF) and the
#              Partial Autocorrelation Function (PACF)

from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(15, 5))
plot_acf(df[period]["rail"], ax=axs[0], lags=35)
axs[0].grid()
plot_pacf(df[period]["rail"], ax=axs[1], lags=35, method="ywm")
axs[1].grid()
plt.show()

# %%
import tensorflow as tf

my_series = [0, 1, 2, 3, 4, 5]
my_dataset = tf.keras.utils.timeseries_dataset_from_array(
    my_series,
    targets=my_series[3:],  # the targets are 3 steps into the future
    sequence_length=3,
    batch_size=2
)
list(my_dataset)
# Out:
# 2023-04-04 23:54:30.098124: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# [(<tf.Tensor: shape=(2, 3), dtype=int32, numpy=
#   array([[0, 1, 2],
#          [1, 2, 3]], dtype=int32)>,
#   <tf.Tensor: shape=(2,), dtype=int32, numpy=array([3, 4], dtype=int32)>),
#  (<tf.Tensor: shape=(1, 3), dtype=int32, numpy=array([[2, 3, 4]], dtype=int32)>,
#   <tf.Tensor: shape=(1,), dtype=int32, numpy=array([5], dtype=int32)>)]

# %%
for window_dataset in tf.data.Dataset.range(6).window(4, shift=1):
    for element in window_dataset:
        print(f"{element}", end=" ")
    print()
# Out:
# 0 1 2 3
# 1 2 3 4
# 2 3 4 5
# 3 4 5
# 4 5
# 5
# 2023-04-04 23:54:32.064289: W tensorflow/core/framework/dataset.cc:769] Input of Window will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# 2023-04-04 23:54:32.078621: W tensorflow/core/data/root_dataset.cc:266] Optimization loop failed: CANCELLED: Operation was cancelled

# %%
dataset = tf.data.Dataset.range(6).window(4, shift=1, drop_remainder=True)
dataset = dataset.flat_map(lambda window_dataset: window_dataset.batch(4))
for window_tensor in dataset:
    print(f"{window_tensor}")
# Out:
# WARNING:tensorflow:From /home/bimri/anaconda3/lib/python3.9/site-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089
# [0 1 2 3]
# [1 2 3 4]
# [2 3 4 5]

# %%
def to_windows(dataset, length):
    dataset = dataset.window(length, shift=1, drop_remainder=True)
    return dataset.flat_map(lambda window_ds: window_ds.batch(length))

# %%
dataset = to_windows(tf.data.Dataset.range(6), 4)
dataset = dataset.map(lambda window: (window[:-1], window[-1]))
list(dataset.batch(2))
# Out:
# [(<tf.Tensor: shape=(2, 3), dtype=int64, numpy=
#   array([[0, 1, 2],
#          [1, 2, 3]])>,
#   <tf.Tensor: shape=(2,), dtype=int64, numpy=array([3, 4])>),
#  (<tf.Tensor: shape=(1, 3), dtype=int64, numpy=array([[2, 3, 4]])>,
#   <tf.Tensor: shape=(1,), dtype=int64, numpy=array([5])>)]

# %% [markdown]
# Before we continue looking at the data, let's split the time series into three periods, for training, validation and testing. We won't look at the test data for now:

# %%
rail_train = df["rail"]["2016-01":"2018-12"] / 1e6
rail_valid = df["rail"]["2019-01":"2019-05"] / 1e6
rail_test = df["rail"]["2019-06":] / 1e6

# %%
seq_length = 56
tf.random.set_seed(42)  # extra code – ensures reproducibility
train_ds = tf.keras.utils.timeseries_dataset_from_array(
    rail_train.to_numpy(),
    targets=rail_train[seq_length:],
    sequence_length=seq_length,
    batch_size=32,
    shuffle=True,
    seed=42
)
valid_ds = tf.keras.utils.timeseries_dataset_from_array(
    rail_valid.to_numpy(),
    targets=rail_valid[seq_length:],
    sequence_length=seq_length,
    batch_size=32
)

# %%
tf.random.set_seed(42)
model = tf.keras.Sequential([
    tf.keras.layers.Dense(1, input_shape=[seq_length])
])
early_stopping_cb = tf.keras.callbacks.EarlyStopping(
    monitor="val_mae", patience=50, restore_best_weights=True)
opt = tf.keras.optimizers.SGD(learning_rate=0.02, momentum=0.9)
model.compile(loss=tf.keras.losses.Huber(), optimizer=opt, metrics=["mae"])
history = model.fit(train_ds, validation_data=valid_ds, epochs=500,
                    callbacks=[early_stopping_cb])
# Out:
# Epoch 1/500
# 33/33 [==============================] - 2s 13ms/step - loss: 0.0168 - mae: 0.1453 - val_loss: 0.0094 - val_mae: 0.1039
# Epoch 2/500
# 33/33 [==============================] - 0s 7ms/step - loss: 0.0101 - mae: 0.1069 - val_loss: 0.0087 - val_mae: 0.0986
# Epoch 3/500
# 33/33 [==============================] - 0s 7ms/step - loss: 0.0090 - mae: 0.1017 - val_loss: 0.0076 - val_mae: 0.0889
# Epoch 4/500
# 33/33 [==============================] - 0s 7ms/step - loss: 0.0079 - mae: 0.0936 - val_loss: 0.0070 - val_mae: 0.0845
# Epoch 5/500
# 33/33 [==============================] - 0s 7ms/step - loss: 0.0072 - mae: 0.0898 - val_loss: 0.0064 - val_mae: 0.0806
# Epoch 6/500
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0067 - mae: 0.0853 - val_loss: 0.0060 - val_mae: 0.0773
# Epoch 7/500
# 33/33 [==============================] - 0s 7ms/step - loss: 0.0061 - mae: 0.0818 - val_loss: 0.0059 - val_mae: 0.0755
# Epoch 8/500
# 33/33 [==============================] - 0s 7ms/step - loss: 0.0062 - mae: 0.0814 - val_loss: 0.0055 - val_mae: 0.0726
# Epoch 9/500
# 33/33 [==============================] - 0s 7ms/step - loss: 0.0062 - mae: 0.0837 - val_loss: 0.0058 - val_mae: 0.0785
# Epoch 10/500
# 33/33 [==============================] - 0s 8ms/step - loss: 0.0056 - mae: 0.0774 - val_loss: 0.0050 - val_mae: 0.0682
# Epoch 11/500
# 33/33 [==============================] - 0s 7ms/step - loss: 0.0054 - mae: 0.0761 - val_loss: 0.0052 - val_mae: 0.0695
# Epoch 12/500
# 33/33 [==============================] - 0s 7ms/step - loss: 0.0051 - mae: 0.0734 - val_loss: 0.0054 - val_mae: 0.0774
# Epoch 13/500
# 33/33 [==============================] - 0s 7ms/step - loss: 0.0053 - mae: 0.0757 - val_loss: 0.0048 - val_mae: 0.0706
# Epoch 14/500
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0051 - mae: 0.0737 - val_loss: 0.0047 - val_mae: 0.0647
# Epoch 15/500
# 33/33 [==============================] - 0s 7ms/step - loss: 0.0048 - mae: 0.0702 - val_loss: 0.0042 - val_mae: 0.0608
# Epoch 16/500
# 33/33 [==============================] - 0s 7ms/step - loss: 0.0047 - mae: 0.0699 - val_loss: 0.0051 - val_mae: 0.0687
# Epoch 17/500
# 33/33 [==============================] - 0s 7ms/step - loss: 0.0047 - mae: 0.0691 - val_loss: 0.0043 - val_mae: 0.0609
# Epoch 18/500
# 33/33 [==============================] - 0s 7ms/step - loss: 0.0043 - mae: 0.0644 - val_loss: 0.0042 - val_mae: 0.0601
# Epoch 19/500
# 33/33 [==============================] - 0s 7ms/step - loss: 0.0040 - mae: 0.0620 - val_loss: 0.0038 - val_mae: 0.0569
# Epoch 20/500
# 33/33 [==============================] - 0s 7ms/step - loss: 0.0040 - mae: 0.0629 - val_loss: 0.0037 - val_mae: 0.0585
# Epoch 21/500
# 33/33 [==============================] - 0s 7ms/step - loss: 0.0040 - mae: 0.0623 - val_loss: 0.0035 - val_mae: 0.0549
# Epoch 22/500
# 33/33 [==============================] - 0s 7ms/step - loss: 0.0038 - mae: 0.0611 - val_loss: 0.0034 - val_mae: 0.0529
# Epoch 23/500
# 33/33 [==============================] - 0s 7ms/step - loss: 0.0036 - mae: 0.0583 - val_loss: 0.0042 - val_mae: 0.0604
# Epoch 24/500
# 33/33 [==============================] - 0s 10ms/step - loss: 0.0038 - mae: 0.0602 - val_loss: 0.0033 - val_mae: 0.0520
# Epoch 25/500
# 33/33 [==============================] - 0s 7ms/step - loss: 0.0035 - mae: 0.0572 - val_loss: 0.0032 - val_mae: 0.0515
# Epoch 26/500
# 33/33 [==============================] - 0s 7ms/step - loss: 0.0036 - mae: 0.0583 - val_loss: 0.0032 - val_mae: 0.0506
# Epoch 27/500
# 33/33 [==============================] - 0s 7ms/step - loss: 0.0036 - mae: 0.0580 - val_loss: 0.0032 - val_mae: 0.0506
# Epoch 28/500
# 33/33 [==============================] - 0s 7ms/step - loss: 0.0037 - mae: 0.0603 - val_loss: 0.0037 - val_mae: 0.0632
# Epoch 29/500
# 33/33 [==============================] - 0s 7ms/step - loss: 0.0035 - mae: 0.0571 - val_loss: 0.0036 - val_mae: 0.0546
# Epoch 30/500
# 33/33 [==============================] - 0s 7ms/step - loss: 0.0036 - mae: 0.0580 - val_loss: 0.0031 - val_mae: 0.0494
# Epoch 31/500
# 33/33 [==============================] - 0s 7ms/step - loss: 0.0034 - mae: 0.0556 - val_loss: 0.0029 - val_mae: 0.0481
# Epoch 32/500
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0033 - mae: 0.0545 - val_loss: 0.0030 - val_mae: 0.0492
# Epoch 33/500
# 33/33 [==============================] - 0s 7ms/step - loss: 0.0032 - mae: 0.0531 - val_loss: 0.0033 - val_mae: 0.0574
# Epoch 34/500
# 33/33 [==============================] - 0s 7ms/step - loss: 0.0033 - mae: 0.0554 - val_loss: 0.0033 - val_mae: 0.0564
# Epoch 35/500
# 33/33 [==============================] - 0s 7ms/step - loss: 0.0032 - mae: 0.0531 - val_loss: 0.0029 - val_mae: 0.0505
# Epoch 36/500
# 33/33 [==============================] - 0s 7ms/step - loss: 0.0031 - mae: 0.0520 - val_loss: 0.0028 - val_mae: 0.0459
# Epoch 37/500
# 33/33 [==============================] - 1s 18ms/step - loss: 0.0032 - mae: 0.0535 - val_loss: 0.0028 - val_mae: 0.0472
# Epoch 38/500
# 33/33 [==============================] - 1s 13ms/step - loss: 0.0031 - mae: 0.0518 - val_loss: 0.0028 - val_mae: 0.0490
# Epoch 39/500
# 33/33 [==============================] - 1s 12ms/step - loss: 0.0032 - mae: 0.0525 - val_loss: 0.0026 - val_mae: 0.0444
# Epoch 40/500
# 33/33 [==============================] - 0s 7ms/step - loss: 0.0031 - mae: 0.0509 - val_loss: 0.0027 - val_mae: 0.0474
# Epoch 41/500
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0030 - mae: 0.0511 - val_loss: 0.0028 - val_mae: 0.0466
# Epoch 42/500
# 33/33 [==============================] - 0s 7ms/step - loss: 0.0031 - mae: 0.0520 - val_loss: 0.0028 - val_mae: 0.0458
# Epoch 43/500
# 33/33 [==============================] - 0s 7ms/step - loss: 0.0034 - mae: 0.0575 - val_loss: 0.0054 - val_mae: 0.0827
# Epoch 44/500
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0032 - mae: 0.0540 - val_loss: 0.0026 - val_mae: 0.0443
# Epoch 45/500
# 33/33 [==============================] - 0s 7ms/step - loss: 0.0031 - mae: 0.0522 - val_loss: 0.0027 - val_mae: 0.0456
# Epoch 46/500
# 33/33 [==============================] - 0s 11ms/step - loss: 0.0030 - mae: 0.0514 - val_loss: 0.0025 - val_mae: 0.0435
# Epoch 47/500
# 33/33 [==============================] - 0s 7ms/step - loss: 0.0028 - mae: 0.0482 - val_loss: 0.0025 - val_mae: 0.0426
# Epoch 48/500
# 33/33 [==============================] - 0s 7ms/step - loss: 0.0029 - mae: 0.0504 - val_loss: 0.0025 - val_mae: 0.0427
# Epoch 49/500
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0028 - mae: 0.0481 - val_loss: 0.0026 - val_mae: 0.0443
# Epoch 50/500
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0031 - mae: 0.0519 - val_loss: 0.0025 - val_mae: 0.0426
# Epoch 51/500
# 33/33 [==============================] - 0s 7ms/step - loss: 0.0028 - mae: 0.0467 - val_loss: 0.0024 - val_mae: 0.0416
# Epoch 52/500
# 33/33 [==============================] - 0s 7ms/step - loss: 0.0028 - mae: 0.0476 - val_loss: 0.0025 - val_mae: 0.0420
# Epoch 53/500
# 33/33 [==============================] - 0s 7ms/step - loss: 0.0029 - mae: 0.0484 - val_loss: 0.0024 - val_mae: 0.0414
# Epoch 54/500
# 33/33 [==============================] - 0s 7ms/step - loss: 0.0028 - mae: 0.0469 - val_loss: 0.0024 - val_mae: 0.0420
# Epoch 55/500
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0029 - mae: 0.0486 - val_loss: 0.0030 - val_mae: 0.0497
# Epoch 56/500
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0030 - mae: 0.0508 - val_loss: 0.0025 - val_mae: 0.0445
# Epoch 57/500
# 33/33 [==============================] - 0s 7ms/step - loss: 0.0028 - mae: 0.0478 - val_loss: 0.0024 - val_mae: 0.0419
# Epoch 58/500
# 33/33 [==============================] - 1s 14ms/step - loss: 0.0028 - mae: 0.0478 - val_loss: 0.0023 - val_mae: 0.0406
# Epoch 59/500
# 33/33 [==============================] - 0s 10ms/step - loss: 0.0027 - mae: 0.0463 - val_loss: 0.0027 - val_mae: 0.0446
# Epoch 60/500
# 33/33 [==============================] - 0s 7ms/step - loss: 0.0028 - mae: 0.0488 - val_loss: 0.0027 - val_mae: 0.0456
# Epoch 61/500
# 33/33 [==============================] - 1s 15ms/step - loss: 0.0028 - mae: 0.0478 - val_loss: 0.0024 - val_mae: 0.0411
# Epoch 62/500
# 33/33 [==============================] - 0s 7ms/step - loss: 0.0027 - mae: 0.0466 - val_loss: 0.0023 - val_mae: 0.0399
# Epoch 63/500
# 33/33 [==============================] - 0s 7ms/step - loss: 0.0027 - mae: 0.0457 - val_loss: 0.0023 - val_mae: 0.0397
# Epoch 64/500
# 33/33 [==============================] - 0s 7ms/step - loss: 0.0028 - mae: 0.0479 - val_loss: 0.0024 - val_mae: 0.0411
# Epoch 65/500
# 33/33 [==============================] - 0s 7ms/step - loss: 0.0031 - mae: 0.0543 - val_loss: 0.0023 - val_mae: 0.0402
# Epoch 66/500
# 33/33 [==============================] - 0s 7ms/step - loss: 0.0028 - mae: 0.0464 - val_loss: 0.0023 - val_mae: 0.0399
# Epoch 67/500
# 33/33 [==============================] - 0s 7ms/step - loss: 0.0028 - mae: 0.0481 - val_loss: 0.0023 - val_mae: 0.0400
# Epoch 68/500
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0028 - mae: 0.0467 - val_loss: 0.0026 - val_mae: 0.0438
# Epoch 69/500
# 33/33 [==============================] - 0s 7ms/step - loss: 0.0028 - mae: 0.0476 - val_loss: 0.0034 - val_mae: 0.0577
# Epoch 70/500
# 33/33 [==============================] - 0s 11ms/step - loss: 0.0029 - mae: 0.0517 - val_loss: 0.0024 - val_mae: 0.0438
# Epoch 71/500
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0028 - mae: 0.0468 - val_loss: 0.0030 - val_mae: 0.0499
# Epoch 72/500
# 33/33 [==============================] - 0s 7ms/step - loss: 0.0028 - mae: 0.0484 - val_loss: 0.0024 - val_mae: 0.0393
# Epoch 73/500
# 33/33 [==============================] - 0s 7ms/step - loss: 0.0027 - mae: 0.0464 - val_loss: 0.0023 - val_mae: 0.0393
# Epoch 74/500
# 33/33 [==============================] - 0s 7ms/step - loss: 0.0027 - mae: 0.0450 - val_loss: 0.0023 - val_mae: 0.0404
# Epoch 75/500
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0026 - mae: 0.0462 - val_loss: 0.0024 - val_mae: 0.0398
# Epoch 76/500
# 33/33 [==============================] - 0s 7ms/step - loss: 0.0027 - mae: 0.0458 - val_loss: 0.0023 - val_mae: 0.0386
# Epoch 77/500
# 33/33 [==============================] - 0s 7ms/step - loss: 0.0028 - mae: 0.0480 - val_loss: 0.0032 - val_mae: 0.0543
# Epoch 78/500
# 33/33 [==============================] - 0s 7ms/step - loss: 0.0029 - mae: 0.0492 - val_loss: 0.0023 - val_mae: 0.0387
# Epoch 79/500
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0028 - mae: 0.0481 - val_loss: 0.0024 - val_mae: 0.0420
# Epoch 80/500
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0027 - mae: 0.0463 - val_loss: 0.0025 - val_mae: 0.0459
# Epoch 81/500
# 33/33 [==============================] - 0s 7ms/step - loss: 0.0027 - mae: 0.0454 - val_loss: 0.0023 - val_mae: 0.0393
# Epoch 82/500
# 33/33 [==============================] - 0s 7ms/step - loss: 0.0026 - mae: 0.0453 - val_loss: 0.0024 - val_mae: 0.0439
# Epoch 83/500
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0026 - mae: 0.0439 - val_loss: 0.0023 - val_mae: 0.0386
# Epoch 84/500
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0026 - mae: 0.0454 - val_loss: 0.0023 - val_mae: 0.0383
# Epoch 85/500
# 33/33 [==============================] - 0s 7ms/step - loss: 0.0026 - mae: 0.0444 - val_loss: 0.0024 - val_mae: 0.0390
# Epoch 86/500
# 33/33 [==============================] - 0s 7ms/step - loss: 0.0026 - mae: 0.0451 - val_loss: 0.0023 - val_mae: 0.0395
# Epoch 87/500
# 33/33 [==============================] - 0s 7ms/step - loss: 0.0027 - mae: 0.0476 - val_loss: 0.0030 - val_mae: 0.0518
# Epoch 88/500
# 33/33 [==============================] - 0s 7ms/step - loss: 0.0031 - mae: 0.0536 - val_loss: 0.0023 - val_mae: 0.0413
# Epoch 89/500
# 33/33 [==============================] - 0s 7ms/step - loss: 0.0026 - mae: 0.0436 - val_loss: 0.0023 - val_mae: 0.0391
# Epoch 90/500
# 33/33 [==============================] - 0s 7ms/step - loss: 0.0028 - mae: 0.0487 - val_loss: 0.0030 - val_mae: 0.0512
# Epoch 91/500
# 33/33 [==============================] - 0s 7ms/step - loss: 0.0027 - mae: 0.0482 - val_loss: 0.0023 - val_mae: 0.0388
# Epoch 92/500
# 33/33 [==============================] - 0s 7ms/step - loss: 0.0026 - mae: 0.0446 - val_loss: 0.0023 - val_mae: 0.0390
# Epoch 93/500
# 33/33 [==============================] - 0s 7ms/step - loss: 0.0026 - mae: 0.0451 - val_loss: 0.0028 - val_mae: 0.0478
# Epoch 94/500
# 33/33 [==============================] - 0s 12ms/step - loss: 0.0031 - mae: 0.0527 - val_loss: 0.0028 - val_mae: 0.0465
# Epoch 95/500
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0028 - mae: 0.0472 - val_loss: 0.0026 - val_mae: 0.0490
# Epoch 96/500
# 33/33 [==============================] - 0s 7ms/step - loss: 0.0027 - mae: 0.0455 - val_loss: 0.0023 - val_mae: 0.0395
# Epoch 97/500
# 33/33 [==============================] - 0s 7ms/step - loss: 0.0026 - mae: 0.0448 - val_loss: 0.0024 - val_mae: 0.0389
# Epoch 98/500
# 33/33 [==============================] - 0s 7ms/step - loss: 0.0025 - mae: 0.0426 - val_loss: 0.0023 - val_mae: 0.0393
# Epoch 99/500
# 33/33 [==============================] - 0s 7ms/step - loss: 0.0026 - mae: 0.0451 - val_loss: 0.0023 - val_mae: 0.0394
# Epoch 100/500
# 33/33 [==============================] - 0s 7ms/step - loss: 0.0025 - mae: 0.0437 - val_loss: 0.0022 - val_mae: 0.0382
# Epoch 101/500
# 33/33 [==============================] - 0s 7ms/step - loss: 0.0025 - mae: 0.0431 - val_loss: 0.0024 - val_mae: 0.0393
# Epoch 102/500
# 33/33 [==============================] - 0s 7ms/step - loss: 0.0029 - mae: 0.0483 - val_loss: 0.0024 - val_mae: 0.0398
# Epoch 103/500
# 33/33 [==============================] - 0s 7ms/step - loss: 0.0027 - mae: 0.0448 - val_loss: 0.0024 - val_mae: 0.0390
# Epoch 104/500
# 33/33 [==============================] - 0s 7ms/step - loss: 0.0027 - mae: 0.0463 - val_loss: 0.0024 - val_mae: 0.0399
# Epoch 105/500
# 33/33 [==============================] - 0s 12ms/step - loss: 0.0027 - mae: 0.0487 - val_loss: 0.0024 - val_mae: 0.0398
# Epoch 106/500
# 33/33 [==============================] - 0s 7ms/step - loss: 0.0026 - mae: 0.0437 - val_loss: 0.0023 - val_mae: 0.0387
# Epoch 107/500
# 33/33 [==============================] - 0s 7ms/step - loss: 0.0027 - mae: 0.0468 - val_loss: 0.0024 - val_mae: 0.0403
# Epoch 108/500
# 33/33 [==============================] - 0s 7ms/step - loss: 0.0026 - mae: 0.0436 - val_loss: 0.0023 - val_mae: 0.0399
# Epoch 109/500
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0026 - mae: 0.0439 - val_loss: 0.0024 - val_mae: 0.0390
# Epoch 110/500
# 33/33 [==============================] - 0s 10ms/step - loss: 0.0025 - mae: 0.0435 - val_loss: 0.0023 - val_mae: 0.0384
# Epoch 111/500
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0027 - mae: 0.0457 - val_loss: 0.0024 - val_mae: 0.0392
# Epoch 112/500
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0027 - mae: 0.0456 - val_loss: 0.0025 - val_mae: 0.0407
# Epoch 113/500
# 33/33 [==============================] - 1s 10ms/step - loss: 0.0026 - mae: 0.0447 - val_loss: 0.0024 - val_mae: 0.0430
# Epoch 114/500
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0027 - mae: 0.0461 - val_loss: 0.0023 - val_mae: 0.0384
# Epoch 115/500
# 33/33 [==============================] - 0s 10ms/step - loss: 0.0031 - mae: 0.0517 - val_loss: 0.0023 - val_mae: 0.0386
# Epoch 116/500
# 33/33 [==============================] - 0s 10ms/step - loss: 0.0025 - mae: 0.0435 - val_loss: 0.0023 - val_mae: 0.0384
# Epoch 117/500
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0028 - mae: 0.0467 - val_loss: 0.0026 - val_mae: 0.0475
# Epoch 118/500
# 33/33 [==============================] - 1s 13ms/step - loss: 0.0026 - mae: 0.0452 - val_loss: 0.0027 - val_mae: 0.0444
# Epoch 119/500
# 33/33 [==============================] - 0s 10ms/step - loss: 0.0030 - mae: 0.0510 - val_loss: 0.0024 - val_mae: 0.0440
# Epoch 120/500
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0026 - mae: 0.0451 - val_loss: 0.0023 - val_mae: 0.0380
# Epoch 121/500
# 33/33 [==============================] - 0s 10ms/step - loss: 0.0026 - mae: 0.0439 - val_loss: 0.0024 - val_mae: 0.0440
# Epoch 122/500
# 33/33 [==============================] - 1s 19ms/step - loss: 0.0027 - mae: 0.0461 - val_loss: 0.0028 - val_mae: 0.0475
# Epoch 123/500
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0028 - mae: 0.0458 - val_loss: 0.0022 - val_mae: 0.0382
# Epoch 124/500
# 33/33 [==============================] - 0s 10ms/step - loss: 0.0026 - mae: 0.0436 - val_loss: 0.0029 - val_mae: 0.0473
# Epoch 125/500
# 33/33 [==============================] - 0s 10ms/step - loss: 0.0028 - mae: 0.0494 - val_loss: 0.0024 - val_mae: 0.0424
# Epoch 126/500
# 33/33 [==============================] - 1s 11ms/step - loss: 0.0032 - mae: 0.0555 - val_loss: 0.0032 - val_mae: 0.0527
# Epoch 127/500
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0027 - mae: 0.0468 - val_loss: 0.0031 - val_mae: 0.0529
# Epoch 128/500
# 33/33 [==============================] - 1s 14ms/step - loss: 0.0029 - mae: 0.0497 - val_loss: 0.0023 - val_mae: 0.0409
# Epoch 129/500
# 33/33 [==============================] - 0s 11ms/step - loss: 0.0025 - mae: 0.0423 - val_loss: 0.0023 - val_mae: 0.0382
# Epoch 130/500
# 33/33 [==============================] - 1s 14ms/step - loss: 0.0026 - mae: 0.0431 - val_loss: 0.0023 - val_mae: 0.0415
# Epoch 131/500
# 33/33 [==============================] - 0s 10ms/step - loss: 0.0025 - mae: 0.0432 - val_loss: 0.0024 - val_mae: 0.0403
# Epoch 132/500
# 33/33 [==============================] - 0s 8ms/step - loss: 0.0026 - mae: 0.0441 - val_loss: 0.0022 - val_mae: 0.0379
# Epoch 133/500
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0026 - mae: 0.0449 - val_loss: 0.0022 - val_mae: 0.0384
# Epoch 134/500
# 33/33 [==============================] - 0s 12ms/step - loss: 0.0026 - mae: 0.0441 - val_loss: 0.0022 - val_mae: 0.0385
# Epoch 135/500
# 33/33 [==============================] - 0s 8ms/step - loss: 0.0026 - mae: 0.0445 - val_loss: 0.0024 - val_mae: 0.0403
# Epoch 136/500
# 33/33 [==============================] - 0s 8ms/step - loss: 0.0026 - mae: 0.0429 - val_loss: 0.0023 - val_mae: 0.0381
# Epoch 137/500
# 33/33 [==============================] - 0s 8ms/step - loss: 0.0028 - mae: 0.0476 - val_loss: 0.0023 - val_mae: 0.0406
# Epoch 138/500
# 33/33 [==============================] - 0s 8ms/step - loss: 0.0028 - mae: 0.0472 - val_loss: 0.0023 - val_mae: 0.0395
# Epoch 139/500
# 33/33 [==============================] - 0s 8ms/step - loss: 0.0027 - mae: 0.0463 - val_loss: 0.0024 - val_mae: 0.0427
# Epoch 140/500
# 33/33 [==============================] - 0s 8ms/step - loss: 0.0025 - mae: 0.0429 - val_loss: 0.0037 - val_mae: 0.0627
# Epoch 141/500
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0026 - mae: 0.0453 - val_loss: 0.0023 - val_mae: 0.0390
# Epoch 142/500
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0026 - mae: 0.0450 - val_loss: 0.0024 - val_mae: 0.0387
# Epoch 143/500
# 33/33 [==============================] - 0s 8ms/step - loss: 0.0029 - mae: 0.0499 - val_loss: 0.0023 - val_mae: 0.0383
# Epoch 144/500
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0028 - mae: 0.0487 - val_loss: 0.0024 - val_mae: 0.0393
# Epoch 145/500
# 33/33 [==============================] - 0s 8ms/step - loss: 0.0028 - mae: 0.0486 - val_loss: 0.0024 - val_mae: 0.0419
# Epoch 146/500
# 33/33 [==============================] - 0s 8ms/step - loss: 0.0025 - mae: 0.0438 - val_loss: 0.0031 - val_mae: 0.0515
# Epoch 147/500
# 33/33 [==============================] - 0s 7ms/step - loss: 0.0028 - mae: 0.0462 - val_loss: 0.0027 - val_mae: 0.0514
# Epoch 148/500
# 33/33 [==============================] - 0s 8ms/step - loss: 0.0025 - mae: 0.0439 - val_loss: 0.0025 - val_mae: 0.0412
# Epoch 149/500
# 33/33 [==============================] - 0s 8ms/step - loss: 0.0026 - mae: 0.0429 - val_loss: 0.0022 - val_mae: 0.0382
# Epoch 150/500
# 33/33 [==============================] - 0s 10ms/step - loss: 0.0026 - mae: 0.0436 - val_loss: 0.0023 - val_mae: 0.0382
# Epoch 151/500
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0026 - mae: 0.0435 - val_loss: 0.0024 - val_mae: 0.0393
# Epoch 152/500
# 33/33 [==============================] - 1s 11ms/step - loss: 0.0026 - mae: 0.0430 - val_loss: 0.0022 - val_mae: 0.0387
# Epoch 153/500
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0026 - mae: 0.0442 - val_loss: 0.0025 - val_mae: 0.0417
# Epoch 154/500
# 33/33 [==============================] - 0s 7ms/step - loss: 0.0029 - mae: 0.0490 - val_loss: 0.0028 - val_mae: 0.0460
# Epoch 155/500
# 33/33 [==============================] - 0s 8ms/step - loss: 0.0026 - mae: 0.0449 - val_loss: 0.0023 - val_mae: 0.0386
# Epoch 156/500
# 33/33 [==============================] - 0s 8ms/step - loss: 0.0027 - mae: 0.0464 - val_loss: 0.0026 - val_mae: 0.0491
# Epoch 157/500
# 33/33 [==============================] - 0s 8ms/step - loss: 0.0025 - mae: 0.0439 - val_loss: 0.0022 - val_mae: 0.0390
# Epoch 158/500
# 33/33 [==============================] - 0s 8ms/step - loss: 0.0027 - mae: 0.0461 - val_loss: 0.0024 - val_mae: 0.0399
# Epoch 159/500
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0027 - mae: 0.0469 - val_loss: 0.0023 - val_mae: 0.0397
# Epoch 160/500
# 33/33 [==============================] - 0s 12ms/step - loss: 0.0028 - mae: 0.0466 - val_loss: 0.0023 - val_mae: 0.0404
# Epoch 161/500
# 33/33 [==============================] - 0s 8ms/step - loss: 0.0032 - mae: 0.0543 - val_loss: 0.0023 - val_mae: 0.0381
# Epoch 162/500
# 33/33 [==============================] - 0s 8ms/step - loss: 0.0026 - mae: 0.0437 - val_loss: 0.0022 - val_mae: 0.0379
# Epoch 163/500
# 33/33 [==============================] - 0s 8ms/step - loss: 0.0026 - mae: 0.0455 - val_loss: 0.0025 - val_mae: 0.0471
# Epoch 164/500
# 33/33 [==============================] - 0s 8ms/step - loss: 0.0027 - mae: 0.0459 - val_loss: 0.0023 - val_mae: 0.0381
# Epoch 165/500
# 33/33 [==============================] - 0s 8ms/step - loss: 0.0025 - mae: 0.0434 - val_loss: 0.0022 - val_mae: 0.0377
# Epoch 166/500
# 33/33 [==============================] - 0s 8ms/step - loss: 0.0028 - mae: 0.0487 - val_loss: 0.0026 - val_mae: 0.0415
# Epoch 167/500
# 33/33 [==============================] - 0s 8ms/step - loss: 0.0026 - mae: 0.0438 - val_loss: 0.0028 - val_mae: 0.0472
# Epoch 168/500
# 33/33 [==============================] - 0s 10ms/step - loss: 0.0028 - mae: 0.0483 - val_loss: 0.0023 - val_mae: 0.0382
# Epoch 169/500
# 33/33 [==============================] - 0s 10ms/step - loss: 0.0026 - mae: 0.0445 - val_loss: 0.0022 - val_mae: 0.0380
# Epoch 170/500
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0028 - mae: 0.0471 - val_loss: 0.0025 - val_mae: 0.0406
# Epoch 171/500
# 33/33 [==============================] - 0s 8ms/step - loss: 0.0026 - mae: 0.0434 - val_loss: 0.0024 - val_mae: 0.0429
# Epoch 172/500
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0027 - mae: 0.0451 - val_loss: 0.0033 - val_mae: 0.0559
# Epoch 173/500
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0025 - mae: 0.0431 - val_loss: 0.0023 - val_mae: 0.0413
# Epoch 174/500
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0027 - mae: 0.0461 - val_loss: 0.0024 - val_mae: 0.0396
# Epoch 175/500
# 33/33 [==============================] - 0s 8ms/step - loss: 0.0027 - mae: 0.0460 - val_loss: 0.0024 - val_mae: 0.0392
# Epoch 176/500
# 33/33 [==============================] - 1s 11ms/step - loss: 0.0028 - mae: 0.0468 - val_loss: 0.0025 - val_mae: 0.0471
# Epoch 177/500
# 33/33 [==============================] - 0s 7ms/step - loss: 0.0025 - mae: 0.0427 - val_loss: 0.0026 - val_mae: 0.0425
# Epoch 178/500
# 33/33 [==============================] - 0s 8ms/step - loss: 0.0027 - mae: 0.0466 - val_loss: 0.0023 - val_mae: 0.0408
# Epoch 179/500
# 33/33 [==============================] - 0s 8ms/step - loss: 0.0026 - mae: 0.0433 - val_loss: 0.0023 - val_mae: 0.0379
# Epoch 180/500
# 33/33 [==============================] - 0s 8ms/step - loss: 0.0028 - mae: 0.0481 - val_loss: 0.0023 - val_mae: 0.0396
# Epoch 181/500
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0026 - mae: 0.0446 - val_loss: 0.0024 - val_mae: 0.0404
# Epoch 182/500
# 33/33 [==============================] - 0s 8ms/step - loss: 0.0025 - mae: 0.0424 - val_loss: 0.0022 - val_mae: 0.0386
# Epoch 183/500
# 33/33 [==============================] - 0s 8ms/step - loss: 0.0025 - mae: 0.0422 - val_loss: 0.0022 - val_mae: 0.0379
# Epoch 184/500
# 33/33 [==============================] - 0s 8ms/step - loss: 0.0025 - mae: 0.0429 - val_loss: 0.0029 - val_mae: 0.0497
# Epoch 185/500
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0031 - mae: 0.0527 - val_loss: 0.0028 - val_mae: 0.0460
# Epoch 186/500
# 33/33 [==============================] - 0s 10ms/step - loss: 0.0028 - mae: 0.0466 - val_loss: 0.0023 - val_mae: 0.0385
# Epoch 187/500
# 33/33 [==============================] - 0s 8ms/step - loss: 0.0026 - mae: 0.0442 - val_loss: 0.0026 - val_mae: 0.0426
# Epoch 188/500
# 33/33 [==============================] - 0s 8ms/step - loss: 0.0028 - mae: 0.0472 - val_loss: 0.0029 - val_mae: 0.0472
# Epoch 189/500
# 33/33 [==============================] - 0s 8ms/step - loss: 0.0029 - mae: 0.0483 - val_loss: 0.0027 - val_mae: 0.0448
# Epoch 190/500
# 33/33 [==============================] - 0s 10ms/step - loss: 0.0027 - mae: 0.0451 - val_loss: 0.0028 - val_mae: 0.0464
# Epoch 191/500
# 33/33 [==============================] - 0s 12ms/step - loss: 0.0028 - mae: 0.0491 - val_loss: 0.0023 - val_mae: 0.0417
# Epoch 192/500
# 33/33 [==============================] - 0s 8ms/step - loss: 0.0032 - mae: 0.0529 - val_loss: 0.0023 - val_mae: 0.0402
# Epoch 193/500
# 33/33 [==============================] - 0s 8ms/step - loss: 0.0027 - mae: 0.0457 - val_loss: 0.0027 - val_mae: 0.0514
# Epoch 194/500
# 33/33 [==============================] - 0s 8ms/step - loss: 0.0029 - mae: 0.0505 - val_loss: 0.0023 - val_mae: 0.0395
# Epoch 195/500
# 33/33 [==============================] - 0s 8ms/step - loss: 0.0025 - mae: 0.0429 - val_loss: 0.0028 - val_mae: 0.0464
# Epoch 196/500
# 33/33 [==============================] - 0s 8ms/step - loss: 0.0026 - mae: 0.0442 - val_loss: 0.0030 - val_mae: 0.0572
# Epoch 197/500
# 33/33 [==============================] - 0s 8ms/step - loss: 0.0025 - mae: 0.0444 - val_loss: 0.0025 - val_mae: 0.0462
# Epoch 198/500
# 33/33 [==============================] - 0s 8ms/step - loss: 0.0031 - mae: 0.0541 - val_loss: 0.0033 - val_mae: 0.0565
# Epoch 199/500
# 33/33 [==============================] - 0s 10ms/step - loss: 0.0027 - mae: 0.0459 - val_loss: 0.0022 - val_mae: 0.0383
# Epoch 200/500
# 33/33 [==============================] - 1s 9ms/step - loss: 0.0027 - mae: 0.0451 - val_loss: 0.0024 - val_mae: 0.0426
# Epoch 201/500
# 33/33 [==============================] - 0s 8ms/step - loss: 0.0026 - mae: 0.0449 - val_loss: 0.0024 - val_mae: 0.0389
# Epoch 202/500
# 33/33 [==============================] - 0s 7ms/step - loss: 0.0028 - mae: 0.0477 - val_loss: 0.0023 - val_mae: 0.0389
# Epoch 203/500
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0026 - mae: 0.0439 - val_loss: 0.0023 - val_mae: 0.0406
# Epoch 204/500
# 33/33 [==============================] - 0s 8ms/step - loss: 0.0025 - mae: 0.0426 - val_loss: 0.0025 - val_mae: 0.0416
# Epoch 205/500
# 33/33 [==============================] - 0s 8ms/step - loss: 0.0027 - mae: 0.0454 - val_loss: 0.0023 - val_mae: 0.0381
# Epoch 206/500
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0025 - mae: 0.0425 - val_loss: 0.0030 - val_mae: 0.0497
# Epoch 207/500
# 33/33 [==============================] - 0s 7ms/step - loss: 0.0028 - mae: 0.0475 - val_loss: 0.0024 - val_mae: 0.0432
# Epoch 208/500
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0025 - mae: 0.0427 - val_loss: 0.0023 - val_mae: 0.0382
# Epoch 209/500
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0025 - mae: 0.0433 - val_loss: 0.0023 - val_mae: 0.0413
# Epoch 210/500
# 33/33 [==============================] - 0s 11ms/step - loss: 0.0025 - mae: 0.0426 - val_loss: 0.0024 - val_mae: 0.0396
# Epoch 211/500
# 33/33 [==============================] - 0s 8ms/step - loss: 0.0026 - mae: 0.0430 - val_loss: 0.0024 - val_mae: 0.0427
# Epoch 212/500
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0026 - mae: 0.0433 - val_loss: 0.0025 - val_mae: 0.0403
# Epoch 213/500
# 33/33 [==============================] - 0s 8ms/step - loss: 0.0027 - mae: 0.0450 - val_loss: 0.0024 - val_mae: 0.0389
# Epoch 214/500
# 33/33 [==============================] - 0s 10ms/step - loss: 0.0029 - mae: 0.0502 - val_loss: 0.0033 - val_mae: 0.0557
# Epoch 215/500
# 33/33 [==============================] - 0s 10ms/step - loss: 0.0029 - mae: 0.0497 - val_loss: 0.0022 - val_mae: 0.0383

# %%
# extra code – evaluates the model
valid_loss, valid_mae = model.evaluate(valid_ds)
valid_mae * 1e6
# Out:
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0022 - mae: 0.0377
# 37744.06015872955

# %% [markdown]
# # Using a Simple RNN

# %%
tf.random.set_seed(42)  # extra code – ensures reproducibility
model = tf.keras.Sequential([
    tf.keras.layers.SimpleRNN(1, input_shape=[None, 1])
])

# %%
# extra code – defines a utility function we'll reuse several time

def fit_and_evaluate(model, train_set, valid_set, learning_rate, epochs=500):
    early_stopping_cb = tf.keras.callbacks.EarlyStopping(
        monitor="val_mae", patience=50, restore_best_weights=True)
    opt = tf.keras.optimizers.SGD(learning_rate=learning_rate, momentum=0.9)
    model.compile(loss=tf.keras.losses.Huber(), optimizer=opt, metrics=["mae"])
    history = model.fit(train_set, validation_data=valid_set, epochs=epochs,
                        callbacks=[early_stopping_cb])
    valid_loss, valid_mae = model.evaluate(valid_set)
    return valid_mae * 1e6

# %%
fit_and_evaluate(model, train_ds, valid_ds, learning_rate=0.02)
# Out:
# Epoch 1/500
# 33/33 [==============================] - 4s 61ms/step - loss: 0.0175 - mae: 0.1579 - val_loss: 0.0183 - val_mae: 0.1286
# Epoch 2/500
# 33/33 [==============================] - 1s 30ms/step - loss: 0.0170 - mae: 0.1571 - val_loss: 0.0161 - val_mae: 0.1592
# Epoch 3/500
# 33/33 [==============================] - 1s 21ms/step - loss: 0.0163 - mae: 0.1625 - val_loss: 0.0174 - val_mae: 0.1336
# Epoch 4/500
# 33/33 [==============================] - 1s 30ms/step - loss: 0.0165 - mae: 0.1564 - val_loss: 0.0166 - val_mae: 0.1416
# Epoch 5/500
# 33/33 [==============================] - 1s 23ms/step - loss: 0.0164 - mae: 0.1568 - val_loss: 0.0161 - val_mae: 0.1550
# Epoch 6/500
# 33/33 [==============================] - 1s 21ms/step - loss: 0.0162 - mae: 0.1599 - val_loss: 0.0162 - val_mae: 0.1493
# Epoch 7/500
# 33/33 [==============================] - 1s 30ms/step - loss: 0.0161 - mae: 0.1593 - val_loss: 0.0170 - val_mae: 0.1379
# Epoch 8/500
# 33/33 [==============================] - 1s 18ms/step - loss: 0.0162 - mae: 0.1592 - val_loss: 0.0169 - val_mae: 0.1387
# Epoch 9/500
# 33/33 [==============================] - 1s 26ms/step - loss: 0.0161 - mae: 0.1598 - val_loss: 0.0165 - val_mae: 0.1452
# Epoch 10/500
# 33/33 [==============================] - 1s 19ms/step - loss: 0.0161 - mae: 0.1589 - val_loss: 0.0164 - val_mae: 0.1475
# Epoch 11/500
# 33/33 [==============================] - 1s 23ms/step - loss: 0.0163 - mae: 0.1596 - val_loss: 0.0170 - val_mae: 0.1383
# Epoch 12/500
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0163 - mae: 0.1599 - val_loss: 0.0164 - val_mae: 0.1460
# Epoch 13/500
# 33/33 [==============================] - 1s 16ms/step - loss: 0.0163 - mae: 0.1593 - val_loss: 0.0162 - val_mae: 0.1519
# Epoch 14/500
# 33/33 [==============================] - 1s 20ms/step - loss: 0.0161 - mae: 0.1598 - val_loss: 0.0166 - val_mae: 0.1426
# Epoch 15/500
# 33/33 [==============================] - 1s 20ms/step - loss: 0.0161 - mae: 0.1581 - val_loss: 0.0165 - val_mae: 0.1444
# Epoch 16/500
# 33/33 [==============================] - 1s 26ms/step - loss: 0.0161 - mae: 0.1578 - val_loss: 0.0164 - val_mae: 0.1452
# Epoch 17/500
# 33/33 [==============================] - 1s 20ms/step - loss: 0.0160 - mae: 0.1595 - val_loss: 0.0164 - val_mae: 0.1467
# Epoch 18/500
# 33/33 [==============================] - 1s 27ms/step - loss: 0.0160 - mae: 0.1587 - val_loss: 0.0168 - val_mae: 0.1400
# Epoch 19/500
# 33/33 [==============================] - 1s 15ms/step - loss: 0.0160 - mae: 0.1583 - val_loss: 0.0168 - val_mae: 0.1393
# Epoch 20/500
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0161 - mae: 0.1581 - val_loss: 0.0164 - val_mae: 0.1443
# Epoch 21/500
# 33/33 [==============================] - 1s 16ms/step - loss: 0.0160 - mae: 0.1578 - val_loss: 0.0164 - val_mae: 0.1443
# Epoch 22/500
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0159 - mae: 0.1576 - val_loss: 0.0162 - val_mae: 0.1489
# Epoch 23/500
# 33/33 [==============================] - 1s 24ms/step - loss: 0.0160 - mae: 0.1592 - val_loss: 0.0164 - val_mae: 0.1434
# Epoch 24/500
# 33/33 [==============================] - 1s 15ms/step - loss: 0.0160 - mae: 0.1573 - val_loss: 0.0163 - val_mae: 0.1456
# Epoch 25/500
# 33/33 [==============================] - 1s 28ms/step - loss: 0.0160 - mae: 0.1574 - val_loss: 0.0161 - val_mae: 0.1515
# Epoch 26/500
# 33/33 [==============================] - 1s 19ms/step - loss: 0.0159 - mae: 0.1595 - val_loss: 0.0165 - val_mae: 0.1416
# Epoch 27/500
# 33/33 [==============================] - 1s 18ms/step - loss: 0.0159 - mae: 0.1574 - val_loss: 0.0164 - val_mae: 0.1428
# Epoch 28/500
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0158 - mae: 0.1574 - val_loss: 0.0163 - val_mae: 0.1439
# Epoch 29/500
# 33/33 [==============================] - 1s 18ms/step - loss: 0.0158 - mae: 0.1576 - val_loss: 0.0161 - val_mae: 0.1475
# Epoch 30/500
# 33/33 [==============================] - 1s 19ms/step - loss: 0.0158 - mae: 0.1570 - val_loss: 0.0163 - val_mae: 0.1431
# Epoch 31/500
# 33/33 [==============================] - 1s 22ms/step - loss: 0.0158 - mae: 0.1566 - val_loss: 0.0159 - val_mae: 0.1499
# Epoch 32/500
# 33/33 [==============================] - 1s 20ms/step - loss: 0.0157 - mae: 0.1573 - val_loss: 0.0159 - val_mae: 0.1521
# Epoch 33/500
# 33/33 [==============================] - 1s 18ms/step - loss: 0.0157 - mae: 0.1561 - val_loss: 0.0163 - val_mae: 0.1412
# Epoch 34/500
# 33/33 [==============================] - 1s 19ms/step - loss: 0.0158 - mae: 0.1570 - val_loss: 0.0162 - val_mae: 0.1419
# Epoch 35/500
# 33/33 [==============================] - 1s 21ms/step - loss: 0.0156 - mae: 0.1577 - val_loss: 0.0163 - val_mae: 0.1399
# Epoch 36/500
# 33/33 [==============================] - 1s 19ms/step - loss: 0.0156 - mae: 0.1561 - val_loss: 0.0162 - val_mae: 0.1408
# Epoch 37/500
# 33/33 [==============================] - 1s 19ms/step - loss: 0.0156 - mae: 0.1555 - val_loss: 0.0158 - val_mae: 0.1469
# Epoch 38/500
# 33/33 [==============================] - 1s 22ms/step - loss: 0.0155 - mae: 0.1558 - val_loss: 0.0159 - val_mae: 0.1452
# Epoch 39/500
# 33/33 [==============================] - 1s 20ms/step - loss: 0.0156 - mae: 0.1564 - val_loss: 0.0171 - val_mae: 0.1321
# Epoch 40/500
# 33/33 [==============================] - 1s 18ms/step - loss: 0.0156 - mae: 0.1567 - val_loss: 0.0160 - val_mae: 0.1419
# Epoch 41/500
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0155 - mae: 0.1535 - val_loss: 0.0157 - val_mae: 0.1463
# Epoch 42/500
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0154 - mae: 0.1544 - val_loss: 0.0157 - val_mae: 0.1459
# Epoch 43/500
# 33/33 [==============================] - 1s 19ms/step - loss: 0.0153 - mae: 0.1563 - val_loss: 0.0159 - val_mae: 0.1412
# Epoch 44/500
# 33/33 [==============================] - 1s 24ms/step - loss: 0.0153 - mae: 0.1558 - val_loss: 0.0163 - val_mae: 0.1359
# Epoch 45/500
# 33/33 [==============================] - 1s 18ms/step - loss: 0.0154 - mae: 0.1545 - val_loss: 0.0158 - val_mae: 0.1409
# Epoch 46/500
# 33/33 [==============================] - 1s 19ms/step - loss: 0.0152 - mae: 0.1548 - val_loss: 0.0157 - val_mae: 0.1417
# Epoch 47/500
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0153 - mae: 0.1539 - val_loss: 0.0157 - val_mae: 0.1406
# Epoch 48/500
# 33/33 [==============================] - 1s 18ms/step - loss: 0.0153 - mae: 0.1546 - val_loss: 0.0158 - val_mae: 0.1383
# Epoch 49/500
# 33/33 [==============================] - 1s 18ms/step - loss: 0.0152 - mae: 0.1549 - val_loss: 0.0157 - val_mae: 0.1392
# Epoch 50/500
# 33/33 [==============================] - 1s 22ms/step - loss: 0.0151 - mae: 0.1532 - val_loss: 0.0155 - val_mae: 0.1421
# Epoch 51/500
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0151 - mae: 0.1541 - val_loss: 0.0158 - val_mae: 0.1372
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0183 - mae: 0.1286
# 128556.9816827774

# %% [markdown]
# # Deep RNNs

# %%
tf.random.set_seed(42)  # extra code – ensures reproducibility
deep_model = tf.keras.Sequential([
    tf.keras.layers.SimpleRNN(32, return_sequences=True, input_shape=[None, 1]),
    tf.keras.layers.SimpleRNN(32, return_sequences=True),
    tf.keras.layers.SimpleRNN(32),
    tf.keras.layers.Dense(1)
])

# %%
# extra code – compiles, fits, and evaluates the model, like earlier
fit_and_evaluate(deep_model, train_ds, valid_ds, learning_rate=0.01)
# Out:
# Epoch 1/500
# 33/33 [==============================] - 5s 58ms/step - loss: 0.0230 - mae: 0.1640 - val_loss: 0.0041 - val_mae: 0.0706
# Epoch 2/500
# 33/33 [==============================] - 1s 39ms/step - loss: 0.0065 - mae: 0.0820 - val_loss: 0.0042 - val_mae: 0.0696
# Epoch 3/500
# 33/33 [==============================] - 1s 39ms/step - loss: 0.0055 - mae: 0.0725 - val_loss: 0.0029 - val_mae: 0.0541
# Epoch 4/500
# 33/33 [==============================] - 2s 49ms/step - loss: 0.0049 - mae: 0.0667 - val_loss: 0.0032 - val_mae: 0.0570
# Epoch 5/500
# 33/33 [==============================] - 1s 40ms/step - loss: 0.0045 - mae: 0.0629 - val_loss: 0.0024 - val_mae: 0.0443
# Epoch 6/500
# 33/33 [==============================] - 2s 47ms/step - loss: 0.0042 - mae: 0.0593 - val_loss: 0.0025 - val_mae: 0.0462
# Epoch 7/500
# 33/33 [==============================] - 2s 46ms/step - loss: 0.0039 - mae: 0.0565 - val_loss: 0.0023 - val_mae: 0.0412
# Epoch 8/500
# 33/33 [==============================] - 2s 50ms/step - loss: 0.0040 - mae: 0.0580 - val_loss: 0.0020 - val_mae: 0.0336
# Epoch 9/500
# 33/33 [==============================] - 2s 52ms/step - loss: 0.0036 - mae: 0.0540 - val_loss: 0.0020 - val_mae: 0.0338
# Epoch 10/500
# 33/33 [==============================] - 2s 44ms/step - loss: 0.0037 - mae: 0.0570 - val_loss: 0.0020 - val_mae: 0.0339
# Epoch 11/500
# 33/33 [==============================] - 2s 49ms/step - loss: 0.0038 - mae: 0.0576 - val_loss: 0.0030 - val_mae: 0.0536
# Epoch 12/500
# 33/33 [==============================] - 2s 55ms/step - loss: 0.0035 - mae: 0.0529 - val_loss: 0.0022 - val_mae: 0.0404
# Epoch 13/500
# 33/33 [==============================] - 1s 41ms/step - loss: 0.0034 - mae: 0.0531 - val_loss: 0.0019 - val_mae: 0.0332
# Epoch 14/500
# 33/33 [==============================] - 2s 44ms/step - loss: 0.0033 - mae: 0.0510 - val_loss: 0.0020 - val_mae: 0.0346
# Epoch 15/500
# 33/33 [==============================] - 2s 50ms/step - loss: 0.0040 - mae: 0.0603 - val_loss: 0.0020 - val_mae: 0.0348
# Epoch 16/500
# 33/33 [==============================] - 1s 43ms/step - loss: 0.0032 - mae: 0.0502 - val_loss: 0.0026 - val_mae: 0.0468
# Epoch 17/500
# 33/33 [==============================] - 2s 45ms/step - loss: 0.0032 - mae: 0.0499 - val_loss: 0.0028 - val_mae: 0.0493
# Epoch 18/500
# 33/33 [==============================] - 2s 54ms/step - loss: 0.0031 - mae: 0.0486 - val_loss: 0.0020 - val_mae: 0.0353
# Epoch 19/500
# 33/33 [==============================] - 2s 60ms/step - loss: 0.0034 - mae: 0.0530 - val_loss: 0.0035 - val_mae: 0.0616
# Epoch 20/500
# 33/33 [==============================] - 2s 51ms/step - loss: 0.0040 - mae: 0.0599 - val_loss: 0.0032 - val_mae: 0.0585
# Epoch 21/500
# 33/33 [==============================] - 2s 47ms/step - loss: 0.0037 - mae: 0.0575 - val_loss: 0.0022 - val_mae: 0.0418
# Epoch 22/500
# 33/33 [==============================] - 1s 41ms/step - loss: 0.0031 - mae: 0.0499 - val_loss: 0.0019 - val_mae: 0.0344
# Epoch 23/500
# 33/33 [==============================] - 1s 42ms/step - loss: 0.0031 - mae: 0.0487 - val_loss: 0.0046 - val_mae: 0.0791
# Epoch 24/500
# 33/33 [==============================] - 2s 45ms/step - loss: 0.0034 - mae: 0.0531 - val_loss: 0.0020 - val_mae: 0.0358
# Epoch 25/500
# 33/33 [==============================] - 1s 42ms/step - loss: 0.0031 - mae: 0.0490 - val_loss: 0.0021 - val_mae: 0.0355
# Epoch 26/500
# 33/33 [==============================] - 1s 42ms/step - loss: 0.0029 - mae: 0.0458 - val_loss: 0.0025 - val_mae: 0.0451
# Epoch 27/500
# 33/33 [==============================] - 2s 42ms/step - loss: 0.0035 - mae: 0.0552 - val_loss: 0.0022 - val_mae: 0.0413
# Epoch 28/500
# 33/33 [==============================] - 2s 61ms/step - loss: 0.0034 - mae: 0.0564 - val_loss: 0.0039 - val_mae: 0.0682
# Epoch 29/500
# 33/33 [==============================] - 2s 48ms/step - loss: 0.0036 - mae: 0.0580 - val_loss: 0.0019 - val_mae: 0.0338
# Epoch 30/500
# 33/33 [==============================] - 1s 42ms/step - loss: 0.0029 - mae: 0.0473 - val_loss: 0.0019 - val_mae: 0.0318
# Epoch 31/500
# 33/33 [==============================] - 2s 47ms/step - loss: 0.0032 - mae: 0.0524 - val_loss: 0.0020 - val_mae: 0.0339
# Epoch 32/500
# 33/33 [==============================] - 1s 40ms/step - loss: 0.0029 - mae: 0.0470 - val_loss: 0.0020 - val_mae: 0.0337
# Epoch 33/500
# 33/33 [==============================] - 1s 41ms/step - loss: 0.0031 - mae: 0.0490 - val_loss: 0.0021 - val_mae: 0.0362
# Epoch 34/500
# 33/33 [==============================] - 2s 47ms/step - loss: 0.0029 - mae: 0.0483 - val_loss: 0.0018 - val_mae: 0.0310
# Epoch 35/500
# 33/33 [==============================] - 1s 41ms/step - loss: 0.0029 - mae: 0.0486 - val_loss: 0.0019 - val_mae: 0.0308
# Epoch 36/500
# 33/33 [==============================] - 1s 41ms/step - loss: 0.0031 - mae: 0.0498 - val_loss: 0.0027 - val_mae: 0.0489
# Epoch 37/500
# 33/33 [==============================] - 1s 43ms/step - loss: 0.0030 - mae: 0.0497 - val_loss: 0.0019 - val_mae: 0.0333
# Epoch 38/500
# 33/33 [==============================] - 2s 47ms/step - loss: 0.0029 - mae: 0.0464 - val_loss: 0.0022 - val_mae: 0.0400
# Epoch 39/500
# 33/33 [==============================] - 2s 62ms/step - loss: 0.0028 - mae: 0.0463 - val_loss: 0.0019 - val_mae: 0.0321
# Epoch 40/500
# 33/33 [==============================] - 1s 42ms/step - loss: 0.0027 - mae: 0.0450 - val_loss: 0.0022 - val_mae: 0.0385
# Epoch 41/500
# 33/33 [==============================] - 2s 43ms/step - loss: 0.0028 - mae: 0.0486 - val_loss: 0.0026 - val_mae: 0.0465
# Epoch 42/500
# 33/33 [==============================] - 2s 47ms/step - loss: 0.0028 - mae: 0.0480 - val_loss: 0.0019 - val_mae: 0.0307
# Epoch 43/500
# 33/33 [==============================] - 1s 42ms/step - loss: 0.0030 - mae: 0.0518 - val_loss: 0.0019 - val_mae: 0.0295
# Epoch 44/500
# 33/33 [==============================] - 1s 41ms/step - loss: 0.0031 - mae: 0.0505 - val_loss: 0.0019 - val_mae: 0.0334
# Epoch 45/500
# 33/33 [==============================] - 1s 41ms/step - loss: 0.0029 - mae: 0.0496 - val_loss: 0.0020 - val_mae: 0.0308
# Epoch 46/500
# 33/33 [==============================] - 1s 41ms/step - loss: 0.0028 - mae: 0.0473 - val_loss: 0.0019 - val_mae: 0.0355
# Epoch 47/500
# 33/33 [==============================] - 2s 43ms/step - loss: 0.0025 - mae: 0.0431 - val_loss: 0.0027 - val_mae: 0.0495
# Epoch 48/500
# 33/33 [==============================] - 1s 43ms/step - loss: 0.0026 - mae: 0.0452 - val_loss: 0.0021 - val_mae: 0.0354
# Epoch 49/500
# 33/33 [==============================] - 1s 42ms/step - loss: 0.0026 - mae: 0.0442 - val_loss: 0.0021 - val_mae: 0.0323
# Epoch 50/500
# 33/33 [==============================] - 2s 43ms/step - loss: 0.0027 - mae: 0.0465 - val_loss: 0.0019 - val_mae: 0.0307
# Epoch 51/500
# 33/33 [==============================] - 1s 41ms/step - loss: 0.0025 - mae: 0.0437 - val_loss: 0.0020 - val_mae: 0.0346
# Epoch 52/500
# 33/33 [==============================] - 2s 43ms/step - loss: 0.0025 - mae: 0.0424 - val_loss: 0.0018 - val_mae: 0.0292
# Epoch 53/500
# 33/33 [==============================] - 1s 41ms/step - loss: 0.0027 - mae: 0.0470 - val_loss: 0.0024 - val_mae: 0.0441
# Epoch 54/500
# 33/33 [==============================] - 2s 45ms/step - loss: 0.0026 - mae: 0.0447 - val_loss: 0.0018 - val_mae: 0.0293
# Epoch 55/500
# 33/33 [==============================] - 1s 41ms/step - loss: 0.0025 - mae: 0.0421 - val_loss: 0.0021 - val_mae: 0.0407
# Epoch 56/500
# 33/33 [==============================] - 2s 44ms/step - loss: 0.0026 - mae: 0.0440 - val_loss: 0.0025 - val_mae: 0.0474
# Epoch 57/500
# 33/33 [==============================] - 1s 41ms/step - loss: 0.0027 - mae: 0.0474 - val_loss: 0.0023 - val_mae: 0.0411
# Epoch 58/500
# 33/33 [==============================] - 1s 41ms/step - loss: 0.0027 - mae: 0.0462 - val_loss: 0.0028 - val_mae: 0.0564
# Epoch 59/500
# 33/33 [==============================] - 2s 44ms/step - loss: 0.0026 - mae: 0.0453 - val_loss: 0.0021 - val_mae: 0.0418
# Epoch 60/500
# 33/33 [==============================] - 1s 41ms/step - loss: 0.0026 - mae: 0.0441 - val_loss: 0.0019 - val_mae: 0.0342
# Epoch 61/500
# 33/33 [==============================] - 2s 46ms/step - loss: 0.0024 - mae: 0.0421 - val_loss: 0.0018 - val_mae: 0.0330
# Epoch 62/500
# 33/33 [==============================] - 1s 42ms/step - loss: 0.0024 - mae: 0.0428 - val_loss: 0.0018 - val_mae: 0.0305
# Epoch 63/500
# 33/33 [==============================] - 1s 42ms/step - loss: 0.0025 - mae: 0.0431 - val_loss: 0.0018 - val_mae: 0.0307
# Epoch 64/500
# 33/33 [==============================] - 2s 42ms/step - loss: 0.0025 - mae: 0.0415 - val_loss: 0.0018 - val_mae: 0.0314
# Epoch 65/500
# 33/33 [==============================] - 2s 46ms/step - loss: 0.0025 - mae: 0.0439 - val_loss: 0.0018 - val_mae: 0.0348
# Epoch 66/500
# 33/33 [==============================] - 2s 44ms/step - loss: 0.0025 - mae: 0.0435 - val_loss: 0.0019 - val_mae: 0.0314
# Epoch 67/500
# 33/33 [==============================] - 1s 41ms/step - loss: 0.0024 - mae: 0.0419 - val_loss: 0.0019 - val_mae: 0.0325
# Epoch 68/500
# 33/33 [==============================] - 2s 45ms/step - loss: 0.0024 - mae: 0.0408 - val_loss: 0.0019 - val_mae: 0.0340
# Epoch 69/500
# 33/33 [==============================] - 1s 43ms/step - loss: 0.0028 - mae: 0.0500 - val_loss: 0.0025 - val_mae: 0.0467
# Epoch 70/500
# 33/33 [==============================] - 1s 42ms/step - loss: 0.0028 - mae: 0.0477 - val_loss: 0.0020 - val_mae: 0.0373
# Epoch 71/500
# 33/33 [==============================] - 2s 47ms/step - loss: 0.0024 - mae: 0.0411 - val_loss: 0.0022 - val_mae: 0.0434
# Epoch 72/500
# 33/33 [==============================] - 1s 41ms/step - loss: 0.0025 - mae: 0.0435 - val_loss: 0.0018 - val_mae: 0.0318
# Epoch 73/500
# 33/33 [==============================] - 1s 41ms/step - loss: 0.0026 - mae: 0.0438 - val_loss: 0.0020 - val_mae: 0.0334
# Epoch 74/500
# 33/33 [==============================] - 2s 47ms/step - loss: 0.0025 - mae: 0.0442 - val_loss: 0.0019 - val_mae: 0.0334
# Epoch 75/500
# 33/33 [==============================] - 2s 43ms/step - loss: 0.0024 - mae: 0.0417 - val_loss: 0.0018 - val_mae: 0.0314
# Epoch 76/500
# 33/33 [==============================] - 1s 41ms/step - loss: 0.0024 - mae: 0.0407 - val_loss: 0.0018 - val_mae: 0.0330
# Epoch 77/500
# 33/33 [==============================] - 2s 47ms/step - loss: 0.0027 - mae: 0.0459 - val_loss: 0.0019 - val_mae: 0.0324
# Epoch 78/500
# 33/33 [==============================] - 1s 42ms/step - loss: 0.0026 - mae: 0.0449 - val_loss: 0.0022 - val_mae: 0.0419
# Epoch 79/500
# 33/33 [==============================] - 2s 52ms/step - loss: 0.0026 - mae: 0.0453 - val_loss: 0.0018 - val_mae: 0.0308
# Epoch 80/500
# 33/33 [==============================] - 1s 41ms/step - loss: 0.0024 - mae: 0.0409 - val_loss: 0.0018 - val_mae: 0.0301
# Epoch 81/500
# 33/33 [==============================] - 2s 46ms/step - loss: 0.0024 - mae: 0.0420 - val_loss: 0.0019 - val_mae: 0.0329
# Epoch 82/500
# 33/33 [==============================] - 1s 41ms/step - loss: 0.0027 - mae: 0.0477 - val_loss: 0.0021 - val_mae: 0.0401
# Epoch 83/500
# 33/33 [==============================] - 2s 45ms/step - loss: 0.0024 - mae: 0.0430 - val_loss: 0.0018 - val_mae: 0.0309
# Epoch 84/500
# 33/33 [==============================] - 1s 41ms/step - loss: 0.0024 - mae: 0.0412 - val_loss: 0.0018 - val_mae: 0.0325
# Epoch 85/500
# 33/33 [==============================] - 1s 41ms/step - loss: 0.0024 - mae: 0.0421 - val_loss: 0.0019 - val_mae: 0.0340
# Epoch 86/500
# 33/33 [==============================] - 2s 47ms/step - loss: 0.0023 - mae: 0.0406 - val_loss: 0.0018 - val_mae: 0.0305
# Epoch 87/500
# 33/33 [==============================] - 1s 41ms/step - loss: 0.0024 - mae: 0.0439 - val_loss: 0.0021 - val_mae: 0.0393
# Epoch 88/500
# 33/33 [==============================] - 1s 43ms/step - loss: 0.0023 - mae: 0.0402 - val_loss: 0.0019 - val_mae: 0.0356
# Epoch 89/500
# 33/33 [==============================] - 2s 45ms/step - loss: 0.0023 - mae: 0.0400 - val_loss: 0.0019 - val_mae: 0.0301
# Epoch 90/500
# 33/33 [==============================] - 1s 41ms/step - loss: 0.0023 - mae: 0.0393 - val_loss: 0.0018 - val_mae: 0.0332
# Epoch 91/500
# 33/33 [==============================] - 1s 43ms/step - loss: 0.0026 - mae: 0.0451 - val_loss: 0.0020 - val_mae: 0.0348
# Epoch 92/500
# 33/33 [==============================] - 2s 46ms/step - loss: 0.0024 - mae: 0.0425 - val_loss: 0.0018 - val_mae: 0.0309
# Epoch 93/500
# 33/33 [==============================] - 1s 41ms/step - loss: 0.0024 - mae: 0.0426 - val_loss: 0.0022 - val_mae: 0.0415
# Epoch 94/500
# 33/33 [==============================] - 1s 43ms/step - loss: 0.0024 - mae: 0.0431 - val_loss: 0.0019 - val_mae: 0.0336
# Epoch 95/500
# 33/33 [==============================] - 2s 46ms/step - loss: 0.0023 - mae: 0.0407 - val_loss: 0.0018 - val_mae: 0.0318
# Epoch 96/500
# 33/33 [==============================] - 1s 41ms/step - loss: 0.0023 - mae: 0.0398 - val_loss: 0.0018 - val_mae: 0.0329
# Epoch 97/500
# 33/33 [==============================] - 2s 51ms/step - loss: 0.0024 - mae: 0.0413 - val_loss: 0.0019 - val_mae: 0.0338
# Epoch 98/500
# 33/33 [==============================] - 1s 41ms/step - loss: 0.0023 - mae: 0.0394 - val_loss: 0.0019 - val_mae: 0.0337
# Epoch 99/500
# 33/33 [==============================] - 1s 41ms/step - loss: 0.0023 - mae: 0.0388 - val_loss: 0.0018 - val_mae: 0.0301
# Epoch 100/500
# 33/33 [==============================] - 2s 43ms/step - loss: 0.0029 - mae: 0.0503 - val_loss: 0.0021 - val_mae: 0.0392
# Epoch 101/500
# 33/33 [==============================] - 1s 42ms/step - loss: 0.0028 - mae: 0.0477 - val_loss: 0.0018 - val_mae: 0.0305
# Epoch 102/500
# 33/33 [==============================] - 2s 44ms/step - loss: 0.0023 - mae: 0.0402 - val_loss: 0.0018 - val_mae: 0.0332
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0018 - mae: 0.0292
# 29156.316071748734

# %% [markdown]
# ## Multivariate time series

# %%
df_mulvar = df[["bus", "rail"]] / 1e6  # use both bus & rail series as input
df_mulvar["next_day_type"] = df["day_type"].shift(-1)  # we know tomorrow's type
df_mulvar = pd.get_dummies(df_mulvar)  # one-hot encode the day type

# %%
mulvar_train = df_mulvar["2016-01":"2018-12"]
mulvar_valid = df_mulvar["2019-01":"2019-05"]
mulvar_test = df_mulvar["2019-06":]

# %%
tf.random.set_seed(42)  # extra code – ensures reproducibility

train_mulvar_ds = tf.keras.utils.timeseries_dataset_from_array(
    mulvar_train.to_numpy(),  # use all 5 columns as input
    targets=mulvar_train["rail"][seq_length:],  # forecast only the rail series
    sequence_length=seq_length,
    batch_size=32,
    shuffle=True,
    seed=42
)
valid_mulvar_ds = tf.keras.utils.timeseries_dataset_from_array(
    mulvar_valid.to_numpy(),
    targets=mulvar_valid["rail"][seq_length:],
    sequence_length=seq_length,
    batch_size=32
)

# %%
tf.random.set_seed(42)  # extra code – ensures reproducibility
mulvar_model = tf.keras.Sequential([
    tf.keras.layers.SimpleRNN(32, input_shape=[None, 5]),
    tf.keras.layers.Dense(1)
])

# %%
# extra code – compiles, fits, and evaluates the model, like earlier
fit_and_evaluate(mulvar_model, train_mulvar_ds, valid_mulvar_ds,
                 learning_rate=0.05)

# %%
# extra code – build and train a multitask RNN that forecasts both bus and rail

tf.random.set_seed(42)

seq_length = 56
train_multask_ds = tf.keras.utils.timeseries_dataset_from_array(
    mulvar_train.to_numpy(),
    targets=mulvar_train[["bus", "rail"]][seq_length:],  # 2 targets per day
    sequence_length=seq_length,
    batch_size=32,
    shuffle=True,
    seed=42
)
valid_multask_ds = tf.keras.utils.timeseries_dataset_from_array(
    mulvar_valid.to_numpy(),
    targets=mulvar_valid[["bus", "rail"]][seq_length:],
    sequence_length=seq_length,
    batch_size=32
)

tf.random.set_seed(42)
multask_model = tf.keras.Sequential([
    tf.keras.layers.SimpleRNN(32, input_shape=[None, 5]),
    tf.keras.layers.Dense(2)
])

fit_and_evaluate(multask_model, train_multask_ds, valid_multask_ds,
                 learning_rate=0.02)

# %%
# extra code – evaluates the naive forecasts for bus
bus_naive = mulvar_valid["bus"].shift(7)[seq_length:]
bus_target = mulvar_valid["bus"][seq_length:]
(bus_target - bus_naive).abs().mean() * 1e6

# %%
# extra code – evaluates the multitask RNN's forecasts both bus and rail
Y_preds_valid = multask_model.predict(valid_multask_ds)
for idx, name in enumerate(["bus", "rail"]):
    mae = 1e6 * tf.keras.metrics.mean_absolute_error(
        mulvar_valid[name][seq_length:], Y_preds_valid[:, idx])
    print(name, int(mae))
